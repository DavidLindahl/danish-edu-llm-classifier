# %%
filepath = "english_fineweb_merged_data.csv"

import pandas as pd
import seaborn as sns

# just read and plot the int_score
df = pd.read_csv(filepath, usecols=["int_score"])
sns.set(style="whitegrid")
ax = sns.histplot(df["int_score"], kde=True, stat="density", bins=30)
