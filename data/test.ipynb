# %%
import pandas as pd
import numpy as np
import seaborn as sns


df = pd.read_csv('english_fineweb_merged_data.csv')

df.head()

len(df)

# histplot of the int_score
sns.histplot(df['int_score'], bins=20, kde=True)
# Out:
# <Axes: xlabel='int_score', ylabel='Count'>
