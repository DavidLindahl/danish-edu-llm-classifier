# %%
import pandas as pd
import numpy as np
import seaborn as sns


df = pd.read_csv('english_fineweb_merged_data.csv')

df.head()

len(df)

# plot the int_score distribution
sns.displot(df['int_score'], kde=True)
